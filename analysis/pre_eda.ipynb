# %%
import pyarrow.parquet as pq

trips = pq.read_table('../data/taxi_data_preprocessed/2020/yellow_tripdata_2020-02.parquet')
trips = trips.to_pandas()

# %%
trips.head()
# Out:
#    DOLocationID  PULocationID  RatecodeID  VendorID  congestion_surcharge  \
# 0            37           249         1.0         1                   2.5
# 1           130            48         NaN         2                   NaN
# 2            80            17         NaN         2                   NaN
# 3           234            90         1.0         2                   2.5
# 4           145           249         1.0         2                   2.5
#
#    extra  fare_amount  improvement_surcharge  mta_tax  passenger_count  \
# 0   3.00        35.50                    0.3      0.5              1.0
# 1   2.75        44.93                    0.3      0.5              NaN
# 2   2.75        19.56                    0.3      0.5              NaN
# 3   0.50         5.00                    0.3      0.5              5.0
# 4   0.50        19.50                    0.3      0.5              6.0
#
#    payment_type store_and_fwd_flag  tip_amount  tolls_amount  total_amount  \
# ...

# %%
print(trips.head())
# Out:
#    DOLocationID  PULocationID  RatecodeID  VendorID  congestion_surcharge  \
# 0            37           249         1.0         1                   2.5
# 1           130            48         NaN         2                   NaN
# 2            80            17         NaN         2                   NaN
# 3           234            90         1.0         2                   2.5
# 4           145           249         1.0         2                   2.5
#
#    extra  fare_amount  improvement_surcharge  mta_tax  passenger_count  \
# 0   3.00        35.50                    0.3      0.5              1.0
# 1   2.75        44.93                    0.3      0.5              NaN
# 2   2.75        19.56                    0.3      0.5              NaN
# 3   0.50         5.00                    0.3      0.5              5.0
# 4   0.50        19.50                    0.3      0.5              6.0
#
#    payment_type store_and_fwd_flag  tip_amount  tolls_amount  total_amount  \
# ...

# %%
trips.columns
# Out:
# Index(['DOLocationID', 'PULocationID', 'RatecodeID', 'VendorID',
#        'congestion_surcharge', 'extra', 'fare_amount', 'improvement_surcharge',
#        'mta_tax', 'passenger_count', 'payment_type', 'store_and_fwd_flag',
#        'tip_amount', 'tolls_amount', 'total_amount', 'tpep_dropoff_datetime',
#        'tpep_pickup_datetime', 'trip_distance', 'Airport_fee', 'trip_id'],
#       dtype='object')
